# %% [markdown]
# <a href="https://colab.research.google.com/github/welcomeglory/Python/blob/master/07_31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
red_path = "/content/drive/MyDrive/세종교육/winequality-red.csv"
white_path ="/content/drive/MyDrive/세종교육/winequality-white.csv"

# %%
red_df = pd.read_csv(red_path, sep=';')
red_df['label'] = 0
red_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white_df = pd.read_csv(white_path, sep=';')
white_df['label'] = 1
white_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine_df = pd.concat([red_df, white_df])
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
wine_df.reset_index(drop=-True, inplace=True)
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
matrix = wine_df.values
matrix
# Out:
# array([[ 7.4 ,  0.7 ,  0.  , ...,  9.4 ,  5.  ,  0.  ],
#        [ 7.8 ,  0.88,  0.  , ...,  9.8 ,  5.  ,  0.  ],
#        [ 7.8 ,  0.76,  0.04, ...,  9.8 ,  5.  ,  0.  ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  9.4 ,  6.  ,  1.  ],
#        [ 5.5 ,  0.29,  0.3 , ..., 12.8 ,  7.  ,  1.  ],
#        [ 6.  ,  0.21,  0.38, ..., 11.8 ,  6.  ,  1.  ]])

# %%
x = matrix[:, :-1] # : 전체 행을 가져옴 :-1 마지막번째 전까지만 가져옴
y = matrix[:, -1] # 맨 마지막 필드만 가져옴
print(x)
print(y) # y값 정답
# Out:
# [[ 7.4   0.7   0.   ...  0.56  9.4   5.  ]
#  [ 7.8   0.88  0.   ...  0.68  9.8   5.  ]
#  [ 7.8   0.76  0.04 ...  0.65  9.8   5.  ]
#  ...
#  [ 6.5   0.24  0.19 ...  0.46  9.4   6.  ]
#  [ 5.5   0.29  0.3  ...  0.38 12.8   7.  ]
#  [ 6.    0.21  0.38 ...  0.32 11.8   6.  ]]
# [0. 0. 0. ... 1. 1. 1.]

# %%
# 정규화
wine_df['fixed acidity'] = (wine_df['fixed acidity'] - wine_df['fixed acidity'].min()) / (wine_df['fixed acidity'].max() - wine_df['fixed acidity'].min())
# wine_df['x2'] = (wine_df['x2'] - wine_df['x2'].min()) / (wine_df['x2'].max() - wine_df['x2'].min())
# wine_df['x3'] = (wine_df['x3'] - wine_df['x3'].min()) / (wine_df['x3'].max() - wine_df['x3'].min())
# wine_df['x4'] = (wine_df['x4'] - wine_df['x4'].min()) / (wine_df['x4'].max() - wine_df['x4'].min())

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.297521              0.70         0.00             1.9      0.076
# 1          0.330579              0.88         0.00             2.6      0.098
# 2          0.330579              0.76         0.04             2.3      0.092
# 3          0.611570              0.28         0.56             1.9      0.075
# 4          0.297521              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492       0.198347              0.21         0.29             1.6      0.039
# 6493       0.231405              0.32         0.36             8.0      0.047
# 6494       0.223140              0.24         0.19             1.2      0.041
# 6495       0.140496              0.29         0.30             1.1      0.022
# 6496       0.181818              0.21         0.38             0.8      0.020
#
# ...
